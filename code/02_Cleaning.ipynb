# %% [markdown]
# # Check (That Tweet) Yo Self
# ## Prioritizing Tweets to Fact Check
# ###### Part 2: Data Cleaning
# In this notebook, we'll clean the tweets we've gathered about Coronavirus.

# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import warnings
import regex as re
import seaborn as sns
import re

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

from nltk.sentiment.vader import SentimentIntensityAnalyzer
warnings.filterwarnings('ignore')
np.random.seed(824)
from bs4 import BeautifulSoup 

# Import stopwords.
from nltk.corpus import stopwords # Import the stopword list
import nltk

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Read in collected dataframe

# %%
tweet = pd.read_csv('../data/all_tweets.csv')

# %% [markdown]
# ### Drop duplicate tweets (a little over 100 tweets removed)

# %%
tweet.shape
# Out:
# (103608, 14)

# %%
tweet.head(2)
# Out:
#                     id   type           time    author  author_id  re_tweeter  \
# 0  1254198473819291649  tweet  1587859192000  PulpNews  100986964         NaN
# 1  1254198461563637763  tweet  1587859189000   aishacs   15809934         NaN
#
#       associated_tweet                                               text  \
# 0  1254198473819291649  Isolation and boredom of staying at home can b...
# 1  1254197958595301386  We left the trail early once we saw that the s...
#
#                          links hashtags mentions  reply_count  favorite_count  \
# 0  ['https://t.co/49b7W0d6V5']       []       []            0               0
# 1                           []       []       []            2              21
#
#    retweet_count
# 0              0
# 1              0

# %%
tweet = tweet.drop_duplicates(subset='id', keep="first")

# %%
tweet.shape
# Out:
# (103492, 14)

# %% [markdown]
# ### Drop "re-tweeter" column: it comprises only null entires
# ### Drop "type" column: it comprises only "tweet" entries, no knowledge gain.

# %%
tweet.isnull().sum()
# Out:
# id                       0
# type                     0
# time                     0
# author                   0
# author_id                0
# re_tweeter          103492
# associated_tweet         0
# text                    14
# links                    0
# hashtags                 0
# mentions                 0
# reply_count              0
# favorite_count           0
# retweet_count            0
# dtype: int64

# %%
tweet['type'].value_counts()
# Out:
# tweet    103492
# Name: type, dtype: int64

# %%
tweet = tweet.drop(columns = ['re_tweeter', 'type'])

# %% [markdown]
# ### Remove additional missing data

# %%
tweet.isnull().sum()
# Out:
# id                   0
# time                 0
# author               0
# author_id            0
# associated_tweet     0
# text                14
# links                0
# hashtags             0
# mentions             0
# reply_count          0
# favorite_count       0
# retweet_count        0
# dtype: int64

# %%
tweet = tweet.dropna()

# %% [markdown]
# ### 1. Convert time column to readable text
# ### 2. Addition of day column to see time distribution of collected tweets

# %%
tweet.dtypes
# Out:
# id                   int64
# time                 int64
# author              object
# author_id            int64
# associated_tweet     int64
# text                object
# links               object
# hashtags            object
# mentions            object
# reply_count          int64
# favorite_count       int64
# retweet_count        int64
# dtype: object

# %%
tweet['time'] = pd.to_numeric(tweet['time'])

import time

def change_time(x):
    x = x / 1000
    return time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x))

tweet['time'] = tweet['time'].apply(change_time)

# %%
def day_classification (string):
    if "2020-04-26" in string:
        return "Sunday"
    elif "2020-04-25" in string:
        return "Saturday"
    elif "2020-04-24" in string:
        return "Friday"
    elif "2020-04-23" in string:
        return "Thursday"

tweet['day'] = tweet['time'].map(day_classification)

# %%
tweet['day'].value_counts()
# Out:
# Saturday    46873
# Friday      39723
# Thursday    11034
# Name: day, dtype: int64

# %% [markdown]
# ### There are 5848 tweets that were collected that aren't within our timeframe of interest. Dropping these tweets from the data

# %%
tweet.isnull().sum()
# Out:
# id                     0
# time                   0
# author                 0
# author_id              0
# associated_tweet       0
# text                   0
# links                  0
# hashtags               0
# mentions               0
# reply_count            0
# favorite_count         0
# retweet_count          0
# day                 5848
# dtype: int64

# %%
tweet = tweet.dropna()

# %% [markdown]
# ### Clean up text to be predominantly recognized as english by the sklearn library

# %%
#set english words
english = set(nltk.corpus.words.words())

def is_english(string):
    #split string up
    words = string.split()
    #start counter
    count = 0
    for word in words:
        #check if the word is in our english list
        if word.lower() not in english:
            count += 1
        #check if any characters are not in the alphabet
        elif word.lower().isalpha() == False:
            count += .33
    perc = round(count / len(words),4)
    #return the proportion of non-english words
    return perc

#apply to this function and create a new column
tweet['not_english'] = tweet['text'].apply(is_english)

# %%
tweet.head(2)
# Out:
#                     id                 time    author  author_id  \
# 0  1254198473819291649  2020-04-25 16:59:52  PulpNews  100986964
# 1  1254198461563637763  2020-04-25 16:59:49   aishacs   15809934
#
#       associated_tweet                                               text  \
# 0  1254198473819291649  Isolation and boredom of staying at home can b...
# 1  1254197958595301386  We left the trail early once we saw that the s...
#
#                          links hashtags mentions  reply_count  favorite_count  \
# 0  ['https://t.co/49b7W0d6V5']       []       []            0               0
# 1                           []       []       []            2              21
#
#    retweet_count       day  not_english
# 0              0  Saturday       0.4800
# 1              0  Saturday       0.2174

# %%
tweet.describe()
# Out:
#                  id     author_id  associated_tweet   reply_count  \
# count  9.763000e+04  9.763000e+04      9.763000e+04  97630.000000
# mean   1.253957e+18  3.914429e+17      1.253282e+18      1.456345
# std    2.441662e+14  5.131221e+17      1.487264e+16     56.718205
# min    1.253218e+18  7.670000e+02      1.507855e+10      0.000000
# 25%    1.253824e+18  2.227531e+08      1.253794e+18      0.000000
# 50%    1.253835e+18  2.259061e+09      1.253834e+18      0.000000
# 75%    1.254191e+18  9.518731e+17      1.254183e+18      1.000000
# max    1.254199e+18  1.254107e+18      1.254199e+18  11718.000000
#
#        favorite_count  retweet_count   not_english
# count    97630.000000   97630.000000  97630.000000
# mean        15.607426       3.845990      0.363189
# std        625.546981     152.979652      0.203048
# min          0.000000       0.000000      0.000000
# 25%          0.000000       0.000000      0.222200
# 50%          0.000000       0.000000      0.312500
# 75%          2.000000       0.000000      0.454500
# max     112659.000000   28381.000000      1.000000

# %% [markdown]
# ### Setting a criteria for amount of english within the tweet
# - Example:
# - (tweet[tweet['not_english'] < .4])
# - less than 40% of the tweet is not identified as english by sklearn (tweet is 60% english)

# %%
tweet[tweet['not_english'] < 0.5]
# Out:
#                          id                 time           author  \
# 0       1254198473819291649  2020-04-25 16:59:52         PulpNews
# 1       1254198461563637763  2020-04-25 16:59:49          aishacs
# 2       1254198450494885893  2020-04-25 16:59:47      nonatofilho
# 3       1254198394022768640  2020-04-25 16:59:33    abbiesbuswell
# 4       1254198364209664000  2020-04-25 16:59:26          Oof_utd
# ...                     ...                  ...              ...
# 103602  1253829172020908032  2020-04-24 16:32:24     JimKingTweet
# 103603  1253829170204798976  2020-04-24 16:32:23   VictorNarraway
# 103604  1253829169080926215  2020-04-24 16:32:23  Stephaniegiann8
# 103605  1253829166861959169  2020-04-24 16:32:23  William48013192
# 103606  1253829166853693440  2020-04-24 16:32:23         usernewm
#
#                   author_id     associated_tweet  \
# 0                 100986964  1254198473819291649
# 1                  15809934  1254197958595301386
# 2                  50183821  1254198450494885893
# 3       1086009979692335108  1254198394022768640
# 4       1243653781679734784  1254198103504228352
# ...                     ...                  ...
# 103602   800030102935306242  1253829172020908032
# 103603   944181190285598724  1253481322141679619
# 103604   763887982898212864  1253751812194070529
# 103605  1198328078688112640  1253801998127857664
# 103606            311637491  1253815999306047492
#
#                                                      text  \
# 0       Isolation and boredom of staying at home can b...
# 1       We left the trail early once we saw that the s...
# 2       During the period of isolation in Brazil, I wa...
# 3       @pritchardfan happy birthday ella !! hope you ...
# 4                                 Had a wank in isolation
# ...                                                   ...
# 103602  Maybe if we promise to drink bleach at dinner ...
# 103603  A frightening 89 thousand approved of Trump's ...
# 103604                   Trump didn’t say to drink bleach
# 103605                               Not drinking bleach?
# 103606  They won't know if the bleach curve is flatten...
#
#                               links hashtags              mentions  \
# 0       ['https://t.co/49b7W0d6V5']       []                    []
# 1                                []       []                    []
# 2                                []       []  ['@realDonaldTrump']
# 3                                []       []     ['@pritchardfan']
# 4                                []       []                    []
# ...                             ...      ...                   ...
# 103602                           []       []                    []
# 103603                           []       []                    []
# 103604                           []       []                    []
# 103605                           []       []                    []
# 103606  ['https://t.co/Mtbc7fBU8U']       []                    []
#
#         reply_count  favorite_count  retweet_count       day  not_english
# 0                 0               0              0  Saturday       0.4800
# 1                 2              21              0  Saturday       0.2174
# 2                 0               1              0  Saturday       0.2857
# 3                 1               1              0  Saturday       0.2143
# 4                 1               1              0  Saturday       0.2000
# ...             ...             ...            ...       ...          ...
# 103602            0               0              0    Friday       0.1111
# 103603            0               0              0    Friday       0.2500
# 103604            0               0              0    Friday       0.1667
# 103605            0               2              0    Friday       0.3333
# 103606            0               0              0    Friday       0.3333
#
# [75468 rows x 14 columns]

# %% [markdown]
# ### using 50% english now, might change that later..

# %%
#only keep words that are more than 50% english
tweet = tweet[tweet['not_english'] < .5]

# %%
tweet.shape
# Out:
# (75468, 14)

# %%
tweet.isnull().sum()
# Out:
# id                  0
# time                0
# author              0
# author_id           0
# associated_tweet    0
# text                0
# links               0
# hashtags            0
# mentions            0
# reply_count         0
# favorite_count      0
# retweet_count       0
# day                 0
# not_english         0
# dtype: int64

# %% [markdown]
# ### Utilize iterable hashtag and mantion items to add columns for counts of hashtags and mentions associated with each tweet

# %%
def to_list(string):
    #remove all unnecessary characters
    string = string.replace('[', '') 
    string = string.replace(']', '') 
    string = string.replace('\'', '')
    #split into list based on commas
    new_list = string.split(',')
    #remove whitespace
    new_list = [x.strip() for x in new_list]
    #return the list
    return new_list

tweet['hashtags'] = tweet['hashtags'].map(to_list)
tweet['mentions'] = tweet['mentions'].map(to_list)

# %%
def count_hash(count_list):
    count = 0
    for i in count_list:
        if '#' in i:
            count += 1
    return count

tweet['hashtag_count'] = tweet['hashtags'].map(count_hash)

# %%
tweet['hashtag_count'].value_counts(normalize = True)
# Out:
# 0     0.863174
# 1     0.066863
# 2     0.029867
# 3     0.017544
# 4     0.009289
# 5     0.005632
# 6     0.002942
# 7     0.002173
# 8     0.000954
# 9     0.000663
# 10    0.000411
# 11    0.000239
# 12    0.000119
# 13    0.000093
# 14    0.000040
# Name: hashtag_count, dtype: float64

# %%
def count_at(count_list):
    count = 0
    for i in count_list:
        if "@" in i:
            count += 1
    return count

tweet['mention_count'] = tweet['mentions'].map(count_at)

# %%
tweet['mention_count'].value_counts(normalize = True)
# Out:
# 0     0.890232
# 1     0.084089
# 2     0.015238
# 3     0.005486
# 4     0.002478
# 5     0.001153
# 6     0.000610
# 7     0.000331
# 8     0.000159
# 9     0.000106
# 10    0.000080
# 11    0.000027
# 12    0.000013
# Name: mention_count, dtype: float64

# %% [markdown]
# ### Create columns for tweet word count and character count

# %%
def word_count(string):
    return len(string.split())

tweet['word_count'] = tweet['text'].map(word_count)

# %%
tweet['word_count'].value_counts(normalize = True)
# Out:
# 15    0.034544
# 13    0.032742
# 16    0.031828
# 17    0.030967
# 11    0.030914
#         ...
# 60    0.000172
# 61    0.000053
# 62    0.000027
# 68    0.000013
# 63    0.000013
# Name: word_count, Length: 64, dtype: float64

# %%
def char_count(string):
    return len(string)

tweet['char_count'] = tweet['text'].map(char_count)

# %%
tweet['char_count'].value_counts(normalize = True)
# Out:
# 280    0.012191
# 279    0.010455
# 278    0.010428
# 277    0.009620
# 276    0.008626
#          ...
# 478    0.000013
# 480    0.000013
# 647    0.000013
# 739    0.000013
# 447    0.000013
# Name: char_count, Length: 486, dtype: float64

# %%
tweet.head(2)
# Out:
#                     id                 time    author  author_id  \
# 0  1254198473819291649  2020-04-25 16:59:52  PulpNews  100986964
# 1  1254198461563637763  2020-04-25 16:59:49   aishacs   15809934
#
#       associated_tweet                                               text  \
# 0  1254198473819291649  Isolation and boredom of staying at home can b...
# 1  1254197958595301386  We left the trail early once we saw that the s...
#
#                          links hashtags mentions  reply_count  favorite_count  \
# 0  ['https://t.co/49b7W0d6V5']       []       []            0               0
# 1                           []       []       []            2              21
#
#    retweet_count       day  not_english  hashtag_count  mention_count  \
# 0              0  Saturday       0.4800              0              0
# 1              0  Saturday       0.2174              0              0
#
#    word_count  char_count
# 0          25         238
# 1          46         253

# %% [markdown]
# ### Adding column for count of attached links to tweet

# %%
tweet['link_count'] = [1 if len(x) > 2 else 0 for x in tweet['links']]

# %% [markdown]
# ### Sentiment Analysis

# %%
def sentiment_score(string):
    sia = SentimentIntensityAnalyzer()
    return sia.polarity_scores(string)['compound']

tweet['text_sentiment'] = tweet['text'].map(sentiment_score)

# %%
tweet.describe()
# Out:
#                  id     author_id  associated_tweet   reply_count  \
# count  7.546800e+04  7.546800e+04      7.546800e+04  75468.000000
# mean   1.253946e+18  3.938128e+17      1.253157e+18      1.602361
# std    2.481303e+14  5.125541e+17      1.629141e+16     63.302824
# min    1.253218e+18  7.670000e+02      1.507855e+10      0.000000
# 25%    1.253822e+18  2.302665e+08      1.253774e+18      0.000000
# 50%    1.253835e+18  2.303449e+09      1.253832e+18      0.000000
# 75%    1.254189e+18  9.512140e+17      1.254176e+18      1.000000
# max    1.254199e+18  1.254107e+18      1.254199e+18  11718.000000
#
#        favorite_count  retweet_count   not_english  hashtag_count  \
# count    75468.000000   75468.000000  75468.000000   75468.000000
# mean        17.340860       3.992328      0.272400       0.300922
# std        701.278927     166.245342      0.102384       0.990340
# min          0.000000       0.000000      0.000000       0.000000
# 25%          0.000000       0.000000      0.200000       0.000000
# 50%          0.000000       0.000000      0.272700       0.000000
# 75%          2.000000       0.000000      0.343800       0.000000
# max     112659.000000   28381.000000      0.491500      14.000000
#
#        mention_count    word_count    char_count    link_count  text_sentiment
# count   75468.000000  75468.000000  75468.000000  75468.000000    75468.000000
# mean        0.156146     25.420297    164.930779      0.307693       -0.030452
# std         0.555433     13.484980     86.561078      0.461542        0.499193
# min         0.000000      1.000000      2.000000      0.000000       -0.990100
# 25%         0.000000     14.000000     92.000000      0.000000       -0.440400
# 50%         0.000000     23.000000    155.000000      0.000000        0.000000
# 75%         0.000000     37.000000    240.000000      1.000000        0.380200
# max        12.000000     68.000000    779.000000      1.000000        0.991700

# %% [markdown]
# # Adding column of text with links removed

# %%
tweet['text_links_removed'] = [re.sub('(\(https:\/\/[^\s]+)|https:\/\/[^\s]+', '', row) for row in tweet['text']]

# %%
# sklearn's stopwords, extracted
sklearn_stopwords = list(CountVectorizer(stop_words = 'english').get_stop_words())
#Custom created list
#custom_stopwords = ['nosleep', 
#                    'scarystories',
#                    'quarantine',
#                    'virus', 
#                    'covid',
#                    'pandemic',
#                    'coronavirus',
#                    'corona',
#                    'don',
#                    've',
#                    'pt',
#                    'didn',
#                    'wasn',
#                    'll',
#                    'shouldn',
#                    'woo',
#                    'hadn'
#                    'notext',
#                   ]
# Personalized stopwords
#personal_stopwords = sklearn_stopwords + custom_stopwords
#print(personal_stopwords)

# %% [markdown]
# ### Alter text data by removing HTML, non-letters, and stopwords in addition to tokenizing and converting text to all lowercase

# %%
def tweet_to_words(raw_tweet):
    
    # 1. Remove HTML.
    tweet_text = BeautifulSoup(raw_tweet).get_text()
    
    # 2. Remove non-letters.
    letters_only = re.sub("[^a-zA-Z]", " ", tweet_text)
    
    # 3. Convert to lower case, split into individual words.
    words = letters_only.lower().split()
    
    # 4. Convert personalized stopwords to set
    stops = set(stopwords.words('english')) #change this command to set(personal_stopwords) if you decide to customize

    # 5. Remove stopwords.
    meaningful_words = [w for w in words if w not in stops]
    
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return(" ".join(meaningful_words))

# %%
# Get the number of subreddits based on the dataframe size.
total_tweets = tweet.shape[0]
print(f'There are {total_tweets} tweets related to coronavirus.')
# Out:
# There are 75468 tweets related to coronavirus.

# %% [markdown]
# ### Apply function to clean our tweet data

# %%
# Initialize an empty list to hold the clean posts.
clean_tweets = []

print("Cleaning and parsing twitter data...")

# Instantiate counter.
j = 0

# For every post in our training set...
for string in tweet['text_links_removed']:
    
    # Convert post to words, then append to clean_train_posts.
    clean_tweets.append(tweet_to_words(string))
    
    # If the index is divisible by 1000, print a message.
    if (j + 1) % 5000 == 0:
        print(f'Tweet {j + 1} of {total_tweets}.')
    
    j += 1
# Out:
# Cleaning and parsing twitter data...
# Tweet 5000 of 75468.
# Tweet 10000 of 75468.
# Tweet 15000 of 75468.
# Tweet 20000 of 75468.
# Tweet 25000 of 75468.
# Tweet 30000 of 75468.
# Tweet 35000 of 75468.
# Tweet 40000 of 75468.
# Tweet 45000 of 75468.
# Tweet 50000 of 75468.
# Tweet 55000 of 75468.
# Tweet 60000 of 75468.
# Tweet 65000 of 75468.
# Tweet 70000 of 75468.
# Tweet 75000 of 75468.

# %% [markdown]
# ### Add cleaned tweet text to dataframe

# %%
tweet = tweet.assign(clean_text = clean_tweets)

# %% [markdown]
# ### Creating word and character count columns for cleaned text

# %%
tweet['clean_word_count'] = tweet['clean_text'].map(word_count)

# %%
tweet['clean_char_count'] = tweet['clean_text'].map(char_count)

# %%
tweet.head()
# Out:
#                     id                 time         author  \
# 0  1254198473819291649  2020-04-25 16:59:52       PulpNews
# 1  1254198461563637763  2020-04-25 16:59:49        aishacs
# 2  1254198450494885893  2020-04-25 16:59:47    nonatofilho
# 3  1254198394022768640  2020-04-25 16:59:33  abbiesbuswell
# 4  1254198364209664000  2020-04-25 16:59:26        Oof_utd
#
#              author_id     associated_tweet  \
# 0            100986964  1254198473819291649
# 1             15809934  1254197958595301386
# 2             50183821  1254198450494885893
# 3  1086009979692335108  1254198394022768640
# 4  1243653781679734784  1254198103504228352
#
#                                                 text  \
# 0  Isolation and boredom of staying at home can b...
# 1  We left the trail early once we saw that the s...
# 2  During the period of isolation in Brazil, I wa...
# 3  @pritchardfan happy birthday ella !! hope you ...
# 4                            Had a wank in isolation
#
#                          links hashtags            mentions  reply_count  ...  \
# 0  ['https://t.co/49b7W0d6V5']       []                  []            0  ...
# 1                           []       []                  []            2  ...
# 2                           []       []  [@realDonaldTrump]            0  ...
# 3                           []       []     [@pritchardfan]            1  ...
# 4                           []       []                  []            1  ...
#
#    hashtag_count  mention_count word_count  char_count  link_count  \
# 0              0              0         25         238           1
# 1              0              0         46         253           0
# 2              0              1         28         168           0
# 3              0              1         14          85           0
# 4              0              0          5          23           0
#
#    text_sentiment                                 text_links_removed  \
# 0         -0.6124  Isolation and boredom of staying at home can b...
# 1         -0.2960  We left the trail early once we saw that the s...
# 2          0.6249  During the period of isolation in Brazil, I wa...
# 3          0.8652  @pritchardfan happy birthday ella !! hope you ...
# 4         -0.4019                            Had a wank in isolation
#
#                                           clean_text  clean_word_count  \
# 0  isolation boredom staying home harmful way doc...                11
# 1  left trail early saw sentiment shifted worried...                24
# 2  period isolation brazil impressed film parasit...                12
# 3  pritchardfan happy birthday ella hope best day...                 9
# 4                                     wank isolation                 2
#
#    clean_char_count
# 0                64
# 1               156
# 2                99
# 3                65
# 4                14
#
# [5 rows x 24 columns]

# %%
tweet.describe()
# Out:
#                  id     author_id  associated_tweet   reply_count  \
# count  7.546800e+04  7.546800e+04      7.546800e+04  75468.000000
# mean   1.253946e+18  3.938128e+17      1.253157e+18      1.602361
# std    2.481303e+14  5.125541e+17      1.629141e+16     63.302824
# min    1.253218e+18  7.670000e+02      1.507855e+10      0.000000
# 25%    1.253822e+18  2.302665e+08      1.253774e+18      0.000000
# 50%    1.253835e+18  2.303449e+09      1.253832e+18      0.000000
# 75%    1.254189e+18  9.512140e+17      1.254176e+18      1.000000
# max    1.254199e+18  1.254107e+18      1.254199e+18  11718.000000
#
#        favorite_count  retweet_count   not_english  hashtag_count  \
# count    75468.000000   75468.000000  75468.000000   75468.000000
# mean        17.340860       3.992328      0.272400       0.300922
# std        701.278927     166.245342      0.102384       0.990340
# min          0.000000       0.000000      0.000000       0.000000
# 25%          0.000000       0.000000      0.200000       0.000000
# 50%          0.000000       0.000000      0.272700       0.000000
# 75%          2.000000       0.000000      0.343800       0.000000
# max     112659.000000   28381.000000      0.491500      14.000000
#
#        mention_count    word_count    char_count    link_count  \
# count   75468.000000  75468.000000  75468.000000  75468.000000
# mean        0.156146     25.420297    164.930779      0.307693
# std         0.555433     13.484980     86.561078      0.461542
# min         0.000000      1.000000      2.000000      0.000000
# 25%         0.000000     14.000000     92.000000      0.000000
# 50%         0.000000     23.000000    155.000000      0.000000
# 75%         0.000000     37.000000    240.000000      1.000000
# max        12.000000     68.000000    779.000000      1.000000
#
#        text_sentiment  clean_word_count  clean_char_count
# count    75468.000000      75468.000000      75468.000000
# mean        -0.030452         14.064517         97.773546
# std          0.499193          7.444092         53.188216
# min         -0.990100          0.000000          0.000000
# 25%         -0.440400          8.000000         54.000000
# 50%          0.000000         13.000000         89.000000
# 75%          0.380200         20.000000        140.000000
# max          0.991700         63.000000        444.000000

# %%
tweet.to_csv('../data/cleaned_with_lysol.csv', index = False)
